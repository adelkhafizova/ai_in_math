# %%
import burau as b
import free_scripts as bf
from itertools import product
import numpy as np 
import json
from importlib import reload
reload(bf)
# Out:
# <module 'free_scripts' from '/Users/borisgolikov/Desktop/Burau/ai_in_math/burau_representation/scripts/free_scripts.py'>

# %%
with open("13.json", "r") as f:
    results = json.load(f)

# %%
results = bf.from_json_to_array(results)

# %%
bf.get_degree_picture(results,13)
# Out:
# {1: 0, 2: 0, 3: 0, 4: 24, 5: 400, 6: 4544, 7: 34064, 8: 167632, 9: 492008, 10: 681952, 11: 509296, 12: 203080, 13: 32764}

# %%
small_results = bf.cut_by_degree(results,7)
new = bf.extend_in_all_ways(small_results,1)

# %%
bf.get_degree_picture(new,14)
# Out:
# {1: 0, 2: 0, 3: 0, 4: 8, 5: 424, 6: 4208, 7: 30528, 8: 81928, 9: 0, 10: 0, 11: 0, 12: 0, 13: 0, 14: 0}

# %%
with open("14.json", "w") as f:
    json.dump(bf.serialize(new),f)

# %%
with open("14.json", "r") as f:
    new = json.load(f)
    new = bf.from_json_to_array(new)
new = bf.extend_in_all_ways(new,1)

# %%
bf.get_degree_picture(new,15)
# Out:
# {1: 0, 2: 0, 3: 0, 4: 0, 5: 336, 6: 3392, 7: 29488, 8: 130816, 9: 187256, 10: 0, 11: 0, 12: 0, 13: 0, 14: 0, 15: 0}
