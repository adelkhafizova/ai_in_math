# %%
import burau as b
import substitute_scripts as bf
from itertools import product, combinations
import numpy as np 
import json
import math
from importlib import reload
reload(bf)
reload(b)
# Out:
# <module 'burau' from '/Users/borisgolikov/Desktop/Burau/ai_in_math/burau_representation/scripts/burau.py'>

# %%
a = bf.calculate_to_n(8)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for key1, key2 in combinations(a.keys(),2):
    if key2 == "A":
        print(key1)
    if np.allclose(a[key1],a[key2]):
        print(key1,key2)
        break
# Out:
# AAAAAAAAA
# AAAAAAAAB
# AAAAAAAAb
# AAAAAAABA
# AAAAAAABB
# AAAAAAABa
# AAAAAAAbA
# AAAAAAAba
# AAAAAAAbb
# AAAAAABAA
# AAAAAABAB
# AAAAAABAb
# AAAAAABBA
# AAAAAABBB
# AAAAAABBa
# AAAAAABaB
# AAAAAABaa
# AAAAAABab
# AAAAAAbAA
# AAAAAAbAB
# AAAAAAbAb
# AAAAAAbaB
# AAAAAAbaa
# AAAAAAbab
# AAAAAAbbA
# AAAAAAbba
# AAAAAAbbb
# AAAAABAAA
# AAAAABAAB
# AAAAABAAb
# AAAAABABA
# AAAAABABB
# AAAAABABa
# AAAAABAbA
# AAAAABAba
# AAAAABAbb
# AAAAABBAA
# AAAAABBAB
# AAAAABBAb
# AAAAABBBA
# AAAAABBBB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 if key2 == "A":
#       3     print(key1)
# ----> 4 if np.allclose(a[key1],a[key2]):
#       5     print(key1,key2)
#       6     break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/_core/numeric.py:2329, in allclose(a, b, rtol, atol, equal_nan)
# ...

# %%
loaded = np.load("matrix.npz", allow_pickle=True)
# Access matrices by key
print(loaded["B"])
